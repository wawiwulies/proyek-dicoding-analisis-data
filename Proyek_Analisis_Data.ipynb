# %% [markdown]
# <a href="https://colab.research.google.com/github/wawiwulies/proyek-dicoding-analisis-data/blob/main/Proyek_Analisis_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Proyek Analisis Data: E-commerce Public Dataset
# - **Nama:** Syahwa Lila Yasmien
# - **Email:** syahwaalila45@gmail.com
# - **ID Dicoding:** -

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# - Apa kategori produk yang paling banyak terjual di e-commerse?
# - Kapan terakhir pelanggan melakukan transaksi?

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import streamlit as st
from scipy import stats

# %%
pip install numpy pandas scipy matplotlib seaborn jupyter

# %%
pip install streamlit
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.9/41.9 kB 1.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 28.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 9.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 36.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.3/79.3 kB 5.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 3.8 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %%
customers_df = pd.read_csv('/content/Data/customers_dataset.csv')
customers_df.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP

# %%
import pandas as pd

order_items_df = pd.read_csv('/content/Data/order_items_dataset.csv')
order_items_df.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value
# 0  2017-09-19 09:45:35   58.90          13.29
# 1  2017-05-03 11:05:13  239.90          19.93
# 2  2018-01-18 14:48:30  199.00          17.87
# 3  2018-08-15 10:10:18   12.99          12.79
# ...

# %%
import pandas as pd

#Membaca file csv
order_payments_df = pd.read_csv('/content/Data/order_payments_dataset.csv')
order_payments_df.head()
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
#
#    payment_installments  payment_value
# 0                     8          99.33
# 1                     1          24.39
# 2                     1          65.71
# 3                     8         107.78
# 4                     2         128.45

# %%
product_category_df = pd.read_csv('/content/Data/products_dataset.csv')
product_category_df.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# ...

# %%
orders_df = pd.read_csv('/content/Data/orders_dataset.csv')
orders_df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %% [markdown]
# **Insight:**
# - Dataset pelanggan memiliki beberapa kolom penting, seperti customer_id, customer_unique_id, customer_zip_code_prefix, customer_city, dan customer_state.
# - Dataset pelanggan menyimpan informasi pelanggan berdasarkan ID unik yang bisa digunakan untuk menghubungkan dengan dataset lainnya seperti pesanan atau transaksi.
#
# - Dataset geolocation berisi informasi tentang analisis lokasi atau memetakan distribusi geografis pelanggan.
#
# - Data geolocation berguna untuk analisis demografis, misalnya mengetahui distribusi pelanggan berdasarkan wilayah geografis.
#
# - Dataset order_items memberikan rincian barang dalam setiap pesanan, termasuk product_id, order_id, price, dan freight_value (biaya pengiriman).
#
# - Dataset order_items begitu penting untuk menghitung total nilai transaksi dan mengidentifikasi produk terlaris yang dimiliki oleh e-commerse.
#
# - Dataset order_payments mencakup informasi tentang metode pembayaran (payment_type), jumlah pembayaran (payment_value), dan pembayaran berulang dalam satu pesanan (payment_installments).
#
# - Dataset order_payments dapat digunakan untuk melihat metode pembayaran yang paling umum digunakan saat melakukan transaksi di e-commerse.
#
# - Dataset product_category memberikan informasi kategori produk yang akan membantu dalam menganalisis produk berdasarkan kategori.
#
# - Dataset ini berisikan deskripsi kategori produk, detail kategori produk pada penjualan di e-commerse.

# %% [markdown]
# ### Assessing Data

# %%
customers_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               99441 non-null  object
#  1   customer_unique_id        99441 non-null  object
#  2   customer_zip_code_prefix  99441 non-null  int64
#  3   customer_city             99441 non-null  object
#  4   customer_state            99441 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 3.8+ MB

# %%
import pandas as pd

# Perintah untuk membaca masing-masing file csv
customers_df = pd.read_csv('/content/Data/customers_dataset.csv')
order_items_df = pd.read_csv('/content/Data/order_items_dataset.csv')
order_payments_df = pd.read_csv('/content/Data/order_payments_dataset.csv')
product_category_df = pd.read_csv('/content/Data/products_dataset.csv')
orders_df = pd.read_csv('/content/Data/orders_dataset.csv')

# Menampilkan 7 baris pertama masing-masing dataset
print("Customers Data:")
print(customers_df.head(7), "\n")  # Menampilkan 7 baris pertama
print("Order Items Data:")
print(order_items_df.head(7), "\n")  # Menampilkan 7 baris pertama
print("Order Payments Data:")
print(order_payments_df.head(7), "\n")  # Memastikan head dipanggil sebagai fungsi
print("Product Category Data:")
print(product_category_df.head(7), "\n")  # Menampilkan 7 baris pertama
print("Orders Data:")
print(orders_df.head(7), "\n")  # Menampilkan 7 baris pertama
# Out:
# Customers Data:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
# 5  879864dab9bc3047522c92c82e1212b8  4c93744516667ad3b8f1fb645a3116a4
# 6  fd826e7cf63160e536e0908c76c3f441  addec96d2e059c80c30fe6871d30d177
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# ...

# %%
# Perintah untuk membaca masing-masing file csv
customers_df = pd.read_csv('/content/Data/customers_dataset.csv')
order_items_df = pd.read_csv('/content/Data/order_items_dataset.csv')
order_payments_df = pd.read_csv('/content/Data/order_payments_dataset.csv')
product_category_df = pd.read_csv('/content/Data/products_dataset.csv')
orders_df = pd.read_csv('/content/Data/orders_dataset.csv')

# Menampilkan info dan deskripsi masing-masing dataset

print("Customers Data Info:")
print(customers_df.info(), "\n")  # Menampilkan informasi tentang dataset customers
print("Customers Data Description:")
print(customers_df.describe(), "\n")  # Menampilkan deskripsi statistik

print("Order Items Data Info:")
print(order_items_df.info(), "\n")  # Menampilkan informasi tentang dataset order items
print("Order Items Data Description:")
print(order_items_df.describe(), "\n")  # Menampilkan deskripsi statistik

print("Order Payments Data Info:")
print(order_payments_df.info(), "\n")  # Menampilkan informasi tentang dataset order payments
print("Order Payments Data Description:")
print(order_payments_df.describe(), "\n")  # Menampilkan deskripsi statistik

print("Product Category Data Info:")
print(product_category_df.info(), "\n")  # Menampilkan informasi tentang dataset produk
print("Product Category Data Description:")
print(product_category_df.describe(), "\n")  # Menampilkan deskripsi statistik

print("Orders Data Info:")
print(orders_df.info(), "\n")  # Menampilkan informasi tentang dataset orders
print("Orders Data Description:")
print(orders_df.describe(), "\n")  # Menampilkan deskripsi statistik
# Out:
# Customers Data Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               99441 non-null  object
#  1   customer_unique_id        99441 non-null  object
#  2   customer_zip_code_prefix  99441 non-null  int64
#  3   customer_city             99441 non-null  object
#  4   customer_state            99441 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 3.8+ MB
# None
#
# Customers Data Description:
#        customer_zip_code_prefix
# count              99441.000000
# mean               35137.474583
# std                29797.938996
# min                 1003.000000
# 25%                11347.000000
# 50%                24416.000000
# 75%                58900.000000
# max                99990.000000
#
# Order Items Data Info:
# <class 'pandas.core.frame.DataFrame'>
# ...

# %% [markdown]
# **Insight:**
#
# **Customer**
#
# - Dataset customer berisi 99,441 entri values dengan informasi terkait pelanggan seperti customer_id, customer_unique_id, customer_zip_code_prefix, customer_city, dan customer_state.
#
# **Order Items Data**
#
# - Dataset ini berisi 112,650 entri terkait item dalam pesanan, dengan informasi data type seperti order_id, product_id, price, dan freight_value.
#
# **Order Payments Data**
#
# - Dataset order_payments berisi 103,886 entri yang mencakup informasi data type dari pembayaran, termasuk payment_type, payment_installments, dan payment_value berdasarkan column yang tertera.
#
# - Data ini penting untuk menganalisis nilai pembayaran dan metode pembayaran yang paling sering digunakan oleh pelanggan saat melakukan proses transaksi di e-commerse.
#
# **Order Data**
#
# - Dataset order_data berisi 99,441 entri pesanan dengan informasi data type yang mencangkup seperti order_status, order_purchase_timestamp, dan order_delivered_customer_date.
#
# - Dataset ini bisa digunakan untuk menganalisis pola pembelian dan status pengiriman pesanan.

# %% [markdown]
# ### Cleaning Data

# %% [markdown]
# Duplikasi Data

# %%
# Perintah untuk membaca masing-masing file csv
customers_df = pd.read_csv('/content/Data/customers_dataset.csv')
order_items_df = pd.read_csv('/content/Data/order_items_dataset.csv')
order_payments_df = pd.read_csv('/content/Data/order_payments_dataset.csv')
product_category_df = pd.read_csv('/content/Data/products_dataset.csv')
orders_df = pd.read_csv('/content/Data/orders_dataset.csv')

# Mengidentifikasi data duplikat pada masing-masing dataset

# Customers Data
print("Duplikasi pada Customers Data:")
duplicates_customers = customers_df[customers_df.duplicated()]
print(duplicates_customers, "\n")  # Menampilkan baris duplikat

# Order Items Data
print("Duplikasi pada Order Items Data:")
duplicates_order_items = order_items_df[order_items_df.duplicated()]
print(duplicates_order_items, "\n")  # Menampilkan baris duplikat

# Order Payments Data
print("Duplikasi pada Order Payments Data:")
duplicates_order_payments = order_payments_df[order_payments_df.duplicated()]
print(duplicates_order_payments, "\n")  # Menampilkan baris duplikat

# Product Category Data
print("Duplikasi pada Product Category Data:")
duplicates_product_category = product_category_df[product_category_df.duplicated()]
print(duplicates_product_category, "\n")  # Menampilkan baris duplikat

# Orders Data
print("Duplikasi pada Orders Data:")
duplicates_orders = orders_df[orders_df.duplicated()]
print(duplicates_orders, "\n")  # Menampilkan baris duplikat
# Out:
# Duplikasi pada Customers Data:
# Empty DataFrame
# Columns: [customer_id, customer_unique_id, customer_zip_code_prefix, customer_city, customer_state]
# Index: []
#
# Duplikasi pada Order Items Data:
# Empty DataFrame
# Columns: [order_id, order_item_id, product_id, seller_id, shipping_limit_date, price, freight_value]
# Index: []
#
# Duplikasi pada Order Payments Data:
# Empty DataFrame
# Columns: [order_id, payment_sequential, payment_type, payment_installments, payment_value]
# Index: []
#
# Duplikasi pada Product Category Data:
# Empty DataFrame
# Columns: [product_id, product_category_name, product_name_lenght, product_description_lenght, product_photos_qty, product_weight_g, product_length_cm, product_height_cm, product_width_cm]
# Index: []
#
# Duplikasi pada Orders Data:
# Empty DataFrame
# Columns: [order_id, customer_id, order_status, order_purchase_timestamp, order_approved_at, order_delivered_carrier_date, order_delivered_customer_date, order_estimated_delivery_date]
# ...

# %%
# Menghapus duplikasi

# Customers
customers_cleaned = customers_df.drop_duplicates()
print(f"Customers Data setelah pembersihan duplikasi: {customers_cleaned.shape[0]} baris")

# Order Payments
order_payments_cleaned = order_payments_df.drop_duplicates()
print(f"Order Payments Dataset setelah pembersihan duplikasi: {order_payments_cleaned.shape[0]} baris")

# Order Items
order_items_cleaned = order_items_df.drop_duplicates()
print(f"Order Items Data setelah pembersihan duplikasi: {order_items_cleaned.shape[0]} baris")

# Orders
orders_cleaned = orders_df.drop_duplicates()
print(f"Orders Data setelah pembersihan duplikasi: {orders_cleaned.shape[0]} baris")
# Out:
# Customers Data setelah pembersihan duplikasi: 99441 baris
# Order Payments Dataset setelah pembersihan duplikasi: 103886 baris
# Order Items Data setelah pembersihan duplikasi: 112650 baris
# Orders Data setelah pembersihan duplikasi: 99441 baris

# %% [markdown]
# Missing Value

# %%
# Mengidentifikasi missing values di setiap dataset

print("Missing values pada Customers Data:")
print(customers_df.isnull().sum(), "\n")

print("Missing values pada Order Items Data:")
print(order_items_df.isnull().sum(), "\n")

print("Missing values pada Order Payments Data:")
print(order_payments_df.isnull().sum(), "\n")

print("Missing values pada Product Category Data:")
print(product_category_df.isnull().sum(), "\n")

print("Missing values pada Orders Data:")
print(orders_df.isnull().sum(), "\n")
# Out:
# Missing values pada Customers Data:
# customer_id                 0
# customer_unique_id          0
# customer_zip_code_prefix    0
# customer_city               0
# customer_state              0
# dtype: int64
#
# Missing values pada Order Items Data:
# order_id               0
# order_item_id          0
# product_id             0
# seller_id              0
# shipping_limit_date    0
# price                  0
# freight_value          0
# dtype: int64
#
# Missing values pada Order Payments Data:
# order_id                0
# payment_sequential      0
# payment_type            0
# payment_installments    0
# payment_value           0
# dtype: int64
#
# Missing values pada Product Category Data:
# product_id                      0
# product_category_name         610
# product_name_lenght           610
# product_description_lenght    610
# product_photos_qty            610
# product_weight_g                2
# product_length_cm               2
# product_height_cm               2
# ...

# %%
# Menghapus baris dengan missing values di setiap dataset

customers_df_cleaned = customers_df.dropna()
order_items_df_cleaned = order_items_df.dropna()
order_payments_df_cleaned = order_payments_df.dropna()
product_category_df_cleaned = product_category_df.dropna()
orders_df_cleaned = orders_df.dropna()

print(f"Customers Data setelah menghapus baris dengan missing values: {customers_df_cleaned.shape[0]} baris")
print(f"Order Items Data setelah menghapus baris dengan missing values: {order_items_df_cleaned.shape[0]} baris")
print(f"Order Payments Data setelah menghapus baris dengan missing values: {order_payments_df_cleaned.shape[0]} baris")
print(f"Product Category Data setelah menghapus baris dengan missing values: {product_category_df_cleaned.shape[0]} baris")
print(f"Orders Data setelah menghapus baris dengan missing values: {orders_df_cleaned.shape[0]} baris")
# Out:
# Customers Data setelah menghapus baris dengan missing values: 99441 baris
# Order Items Data setelah menghapus baris dengan missing values: 112650 baris
# Order Payments Data setelah menghapus baris dengan missing values: 103886 baris
# Product Category Data setelah menghapus baris dengan missing values: 32340 baris
# Orders Data setelah menghapus baris dengan missing values: 96461 baris

# %% [markdown]
# **Insight:**
#
# **Product Category**
#
# - Pembersihan missing values ini memungkinkan dataset kategori produk siap untuk dianalisis tanpa missing data yang dapat mengganggu proses evaluasi produk terlaris atau karakteristik produk.
#
# **Order Data**
#
# - Kolom tanggal seperti order_approved_at dan order_delivered_customer_date yang memiliki missing values diisi menggunakan metode forward fill. Ini berarti missing values diisi dengan nilai dari entri sebelumnya yang memiliki data.
#
# - Kolom yang berisi informasi tanggal (order_approved_at dan order_delivered_customer_date) diubah ke dalam format datetime untuk memudahkan analisis waktu.

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Set style for seaborn
sns.set(style='whitegrid')

# %% [markdown]
# ### Explore Data Customer

# %%
import pandas as pd

# Memuat dataset customers
customers_df = pd.read_csv('/content/Data/customers_dataset.csv')

# Menampilkan info dataset
print(customers_df.info())

# Menampilkan 5 baris pertama dari dataset
print(customers_df.head())

# Menampilkan deskripsi statistik untuk kolom non-numerik dan numerik
print(customers_df.describe(include='all'))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               99441 non-null  object
#  1   customer_unique_id        99441 non-null  object
#  2   customer_zip_code_prefix  99441 non-null  int64
#  3   customer_city             99441 non-null  object
#  4   customer_state            99441 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 3.8+ MB
# None
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
# ...

# %%
# Menghitung jumlah nilai unik di setiap kolom
unique_counts = customers_df.nunique()
print("Jumlah nilai unik di setiap kolom:")
print(unique_counts)
# Out:
# Jumlah nilai unik di setiap kolom:
# customer_id                 99441
# customer_unique_id          96096
# customer_zip_code_prefix    14994
# customer_city                4119
# customer_state                 27
# dtype: int64

# %%
# Menghitung jumlah unique customer per kota
unique_customers_per_city = customers_df.groupby(by="customer_city")['customer_id'].nunique().sort_values(ascending=False)

# Menampilkan hasil unique customer per kota
print("Jumlah Unique Customer per Kota:")
print(unique_customers_per_city)
# Out:
# Jumlah Unique Customer per Kota:
# customer_city
# sao paulo         15540
# rio de janeiro     6882
# belo horizonte     2773
# brasilia           2131
# curitiba           1521
#                   ...
# ibiara                1
# rio espera            1
# rio dos indios        1
# rio dos cedros        1
# lagoao                1
# Name: customer_id, Length: 4119, dtype: int64

# %% [markdown]
# ### Explore Data Category Product

# %%
#Exploring the most Product Categories Sold
# Merge order_items with product categories to explore product sales
merged_df = pd.merge(order_items_df, product_category_df, on='product_id', how='left')

# Group by product category and count the number of products sold in each category
top_categories = merged_df.groupby('product_category_name')['order_item_id'].count().sort_values(ascending=False).head(8)

print(top_categories)
# Out:
# product_category_name
# cama_mesa_banho           11115
# beleza_saude               9670
# esporte_lazer              8641
# moveis_decoracao           8334
# informatica_acessorios     7827
# utilidades_domesticas      6964
# relogios_presentes         5991
# telefonia                  4545
# Name: order_item_id, dtype: int64

# %% [markdown]
# ### Explore Data Orders

# %%
#Transaksi terkini para pelanggan
# Mengubah order_purchase_timestamp menjadi datetime
orders_df['order_purchase_timestamp'] = pd.to_datetime(orders_df['order_purchase_timestamp'])

# temukan tanggal transaksi terkini untuk setiap pelanggan di e-commerce
recent_transaction = orders_df.groupby('customer_id')['order_purchase_timestamp'].max().reset_index()

# Melihat hasil sederhana transaksi
print(recent_transaction.sample(8))
# Out:
#                             customer_id order_purchase_timestamp
# 19053  310d31ae6e46c6bc708865caf0649709      2018-02-02 10:18:03
# 87802  e1a81b9db2bc308ffc7e2ee4f70dd22b      2018-08-02 12:18:36
# 99400  ffe51ba924ffabbb6e1ec2c92e582851      2017-01-20 22:11:31
# 47991  7be2fab6281a2ec4df4b9de1e47d9217      2017-10-18 23:38:10
# 13069  219c684533c856c18d3d31208ece446c      2017-11-16 15:09:26
# 21546  3760ea94d9fc7b3ecf5250afb8715418      2018-03-02 15:01:42
# 48149  7c42a4df52043a235ab15ea2f97c449b      2018-05-12 22:17:59
# 29399  4bd306eb40db1bbd39f4ee8531a983fc      2018-01-12 16:34:27

# %% [markdown]
# **Insight:**
# - xxx
# - xxx

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Pertanyaan 1: Apa kategori produk yang paling banyak terjual di e-commerse?

# %%
import pandas as pd
import matplotlib.pyplot as plt

plt.figure(figsize=(10,6))
sns.barplot(x=top_categories.values, y=top_categories.index)
plt.title('Top 10 Most Sold Product Categories')
plt.xlabel('Number of Items Sold')
plt.ylabel('Product Category')
plt.show()

# %% [markdown]
# Pertanyaan 2: Kapan terakhir pelanggan melakukan transaksi?

# %%
# Mengonversi order_purchase_timestamp menjadi datetime
orders_df['order_purchase_timestamp'] = pd.to_datetime(orders_df['order_purchase_timestamp'])

# Mencari transaksi terakhir setiap pelanggan
recent_transactions = orders_df.groupby('customer_id')['order_purchase_timestamp'].max().reset_index()

# Menampilkan beberapa hasil transaksi terbaru
print("Transaksi Terakhir Pelanggan:")
print(recent_transactions.head(10))
# Out:
# Transaksi Terakhir Pelanggan:
#                         customer_id order_purchase_timestamp
# 0  00012a2ce6f8dcda20d059ce98491703      2017-11-14 16:08:26
# 1  000161a058600d5901f007fab4c27140      2017-07-16 09:40:32
# 2  0001fd6190edaaf884bcaf3d49edf079      2017-02-28 11:06:43
# 3  0002414f95344307404f0ace7a26f1d5      2017-08-16 13:09:20
# 4  000379cdec625522490c315e70c7a9fb      2018-04-02 13:42:17
# 5  0004164d20a9e969af783496f3408652      2017-04-12 08:35:12
# 6  000419c5494106c306a97b5635748086      2018-03-02 17:47:40
# 7  00046a560d407e99b969756e0b10f282      2017-12-18 11:08:30
# 8  00050bf6e01e69d5c0fd612f1bcfb69c      2017-09-17 16:04:44
# 9  000598caf2ef4117407665ac33275130      2018-08-11 12:14:35

# %%
# Mengonversi kolom tanggal pengiriman menjadi datetime
orders_df['order_delivered_customer_date'] = pd.to_datetime(orders_df['order_delivered_customer_date'])

# Menampilkan histogram dari tanggal pengiriman
plt.figure(figsize=(10,6))
sns.histplot(orders_df['order_delivered_customer_date'], bins=50, kde=True)
plt.title('Distribusi Waktu Pengiriman Pesanan')
plt.xlabel('Tanggal Pengiriman')
plt.ylabel('Frekuensi')
plt.show()

# %% [markdown]
# ### Pertanyaan 2: Kapan terakhir pelanggan melakukan transaksi?

# %% [markdown]
# **Insight:**
# - xxx
# - xxx

# %% [markdown]
# ## Conclusion

# %% [markdown]
# - Conclution pertanyaan 1: Apa kategori produk yang paling banyak terjual di e-commerce?
#
# Berdasarkan analisis data penjualan yang sudah dilakukan, kategori produk "cama_mesa_banho" (produk rumah tangga) merupakan kategori produk yang paling banyak terjual, diikuti oleh kategori "beleza_saude" (yang merupakan kategori kecantikan dan kesehatan) dan "esporte_lazer" ( termasuk dalam kategori barang kebutuhan olahraga dan rekreasi). Ini menunjukkan bahwa produk-produk untuk kebutuhan rumah tangga dan kecantikan memiliki permintaan yang tinggi di platform e-commerce.
#
# - Conclution pertanyaan 2: Kapan terakhir pelanggan melakukan transaksi?
#
# Di sini, dikatakan bahwa analisis transaksi terakhir menunjukkan bahwa pelanggan aktif melakukan transaksi sepanjang tahun. Tanggal transaksi terakhir untuk setiap pelanggan berbeda-beda, dengan sebagian besar transaksi terjadi di antara akhir tahun 2017 hingga pertengahan tahun 2018.

# %%
import pandas as pd

# Membaca semua dataset
customers_df = pd.read_csv('/content/Data/customers_dataset.csv')
order_items_df = pd.read_csv('/content/Data/order_items_dataset.csv')
order_payments_df = pd.read_csv('/content/Data/order_payments_dataset.csv')
product_category_df = pd.read_csv('/content/Data/products_dataset.csv')
orders_df = pd.read_csv('/content/Data/orders_dataset.csv')

# Menggabungkan dataset orders dengan customers berdasarkan customer_id
merged_orders_customers = pd.merge(orders_df, customers_df, on='customer_id', how='left')

# Menggabungkan dataset order_items dengan orders-customers berdasarkan order_id
merged_order_items = pd.merge(order_items_df, merged_orders_customers, on='order_id', how='left')

# Menggabungkan dataset order_payments dengan order_items-orders-customers berdasarkan order_id
merged_payments = pd.merge(order_payments_df, merged_order_items, on='order_id', how='left')

# Menggabungkan dataset produk dengan dataset yang sudah digabungkan sebelumnya berdasarkan product_id
all_df = pd.merge(product_category_df, merged_payments, on='product_id', how='left')

# %%
# Menyimpan dataframe gabungan ke dalam all_data.csv
all_df.to_csv('/content/Data/all_data.csv', index=False)

# %%
all_df.to_csv("all_data.csv", index=False)
